# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import seaborn as sns
import numpy as np
import os

# %%
os.chdir(r"c:\Users\lanel\OneDrive\Desktop\Data Analytics info\University of Oregon\UO-Data-Analysis-Project_1\UO-Data-Analysis-Project_1-Video-Game-Marketing\Resources")

current_directory = os.getcwd()

csv_path = os.path.join(current_directory, 'vg_sales_updated.csv')

# Load the CSV file created in Part 1 into a Pandas DataFrame
vg_df = pd.read_csv(csv_path)

# Display sample data
vg_df.head()
# Out:
#    rank                          game_title platform  year         genre  \
# 0     1                          Wii Sports      Wii  2006        Sports
# 1     2                   Super Mario Bros.      NES  1985      Platform
# 2     3                      Mario Kart Wii      Wii  2008        Racing
# 3     4                   Wii Sports Resort      Wii  2009        Sports
# 4     5  Pokémon Red / Green / Blue Version       GB  1998  Role-Playing
#
#     publisher       developer  critic_score  user_score  north_america  \
# 0  Nintendo    Nintendo EAD             7.7         NaN          41.36
# 1  Nintendo    Nintendo EAD            10.0         8.2          29.08
# 2  Nintendo    Nintendo EAD             8.2         9.1          15.91
# 3  Nintendo    Nintendo EAD             8.0         8.8          15.61
# 4  Nintendo      Game Freak             9.4         NaN          11.27
#
#    europe  japan  rest_of_world  global
# 0   29.02   3.77           8.51   82.65
# 1    3.58   6.81           0.77   40.24
# 2   12.92   3.80           3.35   35.98
# 3   10.99   3.29           3.02   32.90
# 4    8.89  10.22           1.00   31.37

# %%
#filter out null values
filtered_df = vg_df[vg_df['critic_score'].notnull()]
filtered_df
# Out:
#       rank                          game_title platform  year  \
# 0        1                          Wii Sports      Wii  2006
# 1        2                   Super Mario Bros.      NES  1985
# 2        3                      Mario Kart Wii      Wii  2008
# 3        4                   Wii Sports Resort      Wii  2009
# 4        5  Pokémon Red / Green / Blue Version       GB  1998
# ...    ...                                 ...      ...   ...
# 2040  2041                      Sea of Thieves       PC  2018
# 2041  2042                           Minecraft       PC  2010
# 2042  2043    Hyrule Warriors: Age of Calamity       NS  2020
# 2043  2044                   Ghost of Tsushima      PS4  2020
# 2044  2045                       Killing Floor       PC  2009
#
#                  genre                         publisher  \
# 0               Sports                        Nintendo
# 1             Platform                        Nintendo
# 2               Racing                        Nintendo
# 3               Sports                        Nintendo
# 4         Role-Playing                        Nintendo
# ...                ...                               ...
# 2040  Action-Adventure               Microsoft Studios
# 2041              Misc                          Mojang
# 2042            Action                        Nintendo
# 2043  Action-Adventure  Sony Interactive Entertainment
# 2044           Shooter            Tripwire Interactive
#
#                    developer  critic_score  user_score  north_america  europe  \
# 0             Nintendo EAD             7.7         NaN          41.36   29.02
# 1             Nintendo EAD            10.0         8.2          29.08    3.58
# 2             Nintendo EAD             8.2         9.1          15.91   12.92
# 3             Nintendo EAD             8.0         8.8          15.61   10.99
# 4               Game Freak             9.4         NaN          11.27    8.89
# ...                      ...           ...         ...            ...     ...
# 2040             Rare Ltd.             6.7         NaN            NaN     NaN
# 2041             Mojang AB            10.0         NaN            NaN     NaN
# 2042      Koei Tecmo Games             9.0         NaN            NaN     NaN
# 2043          Sucker Punch             8.8         NaN            NaN     NaN
# 2044  Tripwire Interactive             7.5         NaN            NaN     NaN
#
#       japan  rest_of_world  global
# 0      3.77           8.51   82.65
# 1      6.81           0.77   40.24
# 2      3.80           3.35   35.98
# 3      3.29           3.02   32.90
# 4     10.22           1.00   31.37
# ...     ...            ...     ...
# 2040    NaN            NaN     NaN
# 2041    NaN            NaN     NaN
# 2042    NaN            NaN     NaN
# 2043    NaN            NaN     NaN
# 2044    NaN            NaN     NaN
#
# [1249 rows x 14 columns]

# %%
#remove double spaces from Developer and Publisher
filtered_df['publisher'] = filtered_df['publisher'].str.replace('  ', '')
filtered_df['developer'] = filtered_df['developer'].str.replace('  ', '')
# Out:
# C:\Users\lanel\AppData\Local\Temp\ipykernel_19812\1592770088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['publisher'] = filtered_df['publisher'].str.replace('  ', '')
# C:\Users\lanel\AppData\Local\Temp\ipykernel_19812\1592770088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['developer'] = filtered_df['developer'].str.replace('  ', '')

# %%
#filter out publishers with less than 10 games to gheir name
game_counts_pub = filtered_df['publisher'].value_counts()
game_counts_pub_10 = game_counts_pub[game_counts_pub < 10].reset_index()
less_thatn_10 = game_counts_pub_10["index"].tolist()
filtered_df_pub = filtered_df[filtered_df['publisher'].isin(less_thatn_10) == False]
filtered_df_pub
# Out:
#       rank                          game_title platform  year         genre  \
# 0        1                          Wii Sports      Wii  2006        Sports
# 1        2                   Super Mario Bros.      NES  1985      Platform
# 2        3                      Mario Kart Wii      Wii  2008        Racing
# 3        4                   Wii Sports Resort      Wii  2009        Sports
# 4        5  Pokémon Red / Green / Blue Version       GB  1998  Role-Playing
# ...    ...                                 ...      ...   ...           ...
# 2027  2028                        Just Cause 2       PC  2010        Action
# 2030  2031       Warhammer 40,000: Dawn of War       PC  2004      Strategy
# 2036  2037                        SimCity 3000       PC  1998    Simulation
# 2037  2038            Half-Life 2: Episode One       PC  2006       Shooter
# 2042  2043    Hyrule Warriors: Age of Calamity       NS  2020        Action
#
#               publisher          developer  critic_score  user_score  \
# 0              Nintendo       Nintendo EAD           7.7         NaN
# 1              Nintendo       Nintendo EAD          10.0         8.2
# 2              Nintendo       Nintendo EAD           8.2         9.1
# 3              Nintendo       Nintendo EAD           8.0         8.8
# 4              Nintendo         Game Freak           9.4         NaN
# ...                 ...                ...           ...         ...
# 2027  Eidos Interactive  Avalanche Studios           8.2         NaN
# 2030                THQ              Relic           8.8         NaN
# 2036    Electronic Arts              Maxis           8.5         NaN
# 2037    Electronic Arts     Valve Software           8.7         NaN
# 2042           Nintendo   Koei Tecmo Games           9.0         NaN
#
#       north_america  europe  japan  rest_of_world  global
# 0             41.36   29.02   3.77           8.51   82.65
# 1             29.08    3.58   6.81           0.77   40.24
# 2             15.91   12.92   3.80           3.35   35.98
# 3             15.61   10.99   3.29           3.02   32.90
# 4             11.27    8.89  10.22           1.00   31.37
# ...             ...     ...    ...            ...     ...
# 2027            NaN    0.11    NaN           0.02    0.12
# 2030           0.01    0.04    NaN           0.00    0.05
# 2036            NaN    0.00    NaN           0.00    0.00
# 2037            NaN    0.00    NaN           0.00    0.00
# 2042            NaN     NaN    NaN            NaN     NaN
#
# [1105 rows x 14 columns]

# %%
#repeat for developers
game_counts_dev = filtered_df['developer'].value_counts()
game_counts_dev_10 = game_counts_dev[game_counts_dev < 10].reset_index()
less_thatn_10_dev = game_counts_dev_10["index"].tolist()

filtered_df_dev = filtered_df[filtered_df['developer'].isin(less_thatn_10_dev) == False]

# %%
#group by each publisher and find the mean critic score of each
grouped_vg_df_pub = filtered_df_pub.groupby(['publisher'])
grouped_vg_df_pub_mean=grouped_vg_df_pub['critic_score'].mean().reset_index()
grouped_vg_df_pub_mean=grouped_vg_df_pub_mean.sort_values(by='critic_score')
pd.set_option('display.max_rows', None)
grouped_vg_df_pub_mean.set_index("publisher")
# Out:
#                                         critic_score
# publisher
# THQ                                         7.337209
# Sega                                        7.427273
# Warner Bros. Interactive Entertainment      7.520000
# LucasArts                                   7.703846
# Konami Digital Entertainment                7.892593
# Ubisoft                                     7.908333
# Midway Games                                7.910000
# Codemasters                                 8.066667
# Electronic Arts                             8.081667
# Activision                                  8.113592
# Square Enix                                 8.126471
# Namco Bandai Games                          8.140000
# Nintendo                                    8.332143
# Sony Computer Entertainment                 8.345098
# Eidos Interactive                           8.383333
# Microsoft Game Studios                      8.430303
# Capcom                                      8.440909
# Square                                      8.475000
# Bethesda Softworks                          8.513333
# Take-Two Interactive                        8.514894
# EA Sports                                   8.707692
# Rockstar Games                              9.438462

# %%
os.chdir(r"c:\Users\lanel\OneDrive\Desktop\Data Analytics info\University of Oregon\UO-Data-Analysis-Project_1\UO-Data-Analysis-Project_1-Video-Game-Marketing\critic_score_bias Visuals")

current_directory = os.getcwd()

# %%
#create bar chart comparing the averate critic review for each publisher
vg_bar_pub = grouped_vg_df_pub_mean.plot(kind = "bar", figsize=(20,5))
vg_bar_pub.set_xticklabels(grouped_vg_df_pub_mean["publisher"], rotation=45, ha='right', rotation_mode='anchor')

plt.ylim([5, 10])
plt.grid(axis = 'y')
csv_path = os.path.join(current_directory, 'pub_bar.png')
plt.savefig(csv_path)
plt.show()

# %%
top_5_means = filtered_df[filtered_df["publisher"].isin(['Square', 'Bethesda Softworks', 'Take-Two Interactive', 'EA Sports',
                                                                         'Rockstar Games'])]
sns.set(rc={"figure.figsize":(6, 5)})
outlier_map = sns.boxplot(x="publisher", y="critic_score", data=top_5_means, order=['Square', 'Bethesda Softworks', 'Take-Two Interactive', 'EA Sports',
                                                                         'Rockstar Games'])
plt.xticks(rotation=45, ha='right', rotation_mode='anchor')

csv_path = os.path.join(current_directory, 'pub_box.png')
plt.savefig(csv_path)

# %%
#Go through the same steps above with Developers
grouped_vg_df_dev = filtered_df_dev.groupby(['developer'])
grouped_vg_df_dev_mean=grouped_vg_df_dev['critic_score'].mean().reset_index()
grouped_vg_df_dev_mean=grouped_vg_df_dev_mean.sort_values(by='critic_score')
pd.set_option('display.max_rows', None)
grouped_vg_df_dev_mean.set_index("developer")
# Out:
#                                      critic_score
# developer
# Sonic Team                               6.813333
# Konami                                   6.886667
# Maxis                                    6.972727
# Sega                                     7.330769
# Traveller's Tales                        7.592105
# Vicarious Visions                        7.750000
# Square Enix                              7.805556
# HAL Laboratory                           7.890000
# EA Black Box                             7.911765
# Treyarch                                 8.100000
# Level 5                                  8.308333
# Rare Ltd.                                8.400000
# Capcom                                   8.415152
# Intelligent Systems                      8.440000
# Namco                                    8.480000
# Ubisoft Montreal                         8.489286
# EA Canada                                8.548485
# EA Tiburon                               8.586667
# Game Freak                               8.593333
# Nintendo EAD                             8.603030
# Insomniac Games                          8.650000
# SquareSoft                               8.680952
# Polyphony Digital                        8.750000
# Infinity Ward                            8.791667
# Konami Computer Entertainment Tokyo      8.810000
# Visual Concepts                          8.881818
# Harmonix Music Systems                   8.960000
# Naughty Dog                              9.054545
# Blizzard Entertainment                   9.083333
# Neversoft Entertainment                  9.290909
# Valve Software                           9.400000
# Rockstar North                           9.414286

# %%
vg_bar_dev = grouped_vg_df_dev_mean.plot(kind = "bar", figsize=(20,5))
vg_bar_dev.set_xticklabels(grouped_vg_df_dev_mean["developer"], rotation=45, ha='right', rotation_mode='anchor')

plt.ylim([5, 10])
plt.grid(axis = 'x')
csv_path = os.path.join(current_directory, 'dev_bar.png')
plt.savefig(csv_path)
plt.show()

# %%
top_10_means = filtered_df[filtered_df["developer"].isin(['Polyphony Digital', 'Infinity Ward', 'Konami Computer Entertainment Tokyo', 'Visual Concepts',
                                                                         'Harmonix Music Systems', 'Naughty Dog', 'Blizzard Entertainment', 'Neversoft Entertainment',
                                                                         'Valve Software', 'Rockstar North'])]
sns.set(rc={"figure.figsize":(15, 5)})
outlier_map = sns.boxplot(x="developer", y="critic_score", data=top_10_means, order=['Polyphony Digital', 'Infinity Ward', 'Konami Computer Entertainment Tokyo', 'Visual Concepts',
                                                                         'Harmonix Music Systems', 'Naughty Dog', 'Blizzard Entertainment', 'Neversoft Entertainment',
                                                                         'Valve Software', 'Rockstar North'])
plt.xticks(rotation=45, ha='right', rotation_mode='anchor')

csv_path = os.path.join(current_directory, 'dev_box.png')
plt.savefig(csv_path)
